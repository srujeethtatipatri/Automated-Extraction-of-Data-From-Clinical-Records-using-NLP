# %% [markdown]
#  Return of a Portfolio of Securities

# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
#Load the data
tickers = ['AAPL', 'WMT', 'RBC', 'F', 'AMZN']
mydata = pd.DataFrame()
for t in tickers:
    mydata[t] = wb.DataReader(t, data_source='yahoo', start='2016-1-1')['Close']

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1302 entries, 2016-01-04 to 2021-03-05
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    1302 non-null   float64
#  1   WMT     1302 non-null   float64
#  2   RBC     1302 non-null   float64
#  3   F       1302 non-null   float64
#  4   AMZN    1302 non-null   float64
# dtypes: float64(5)
# memory usage: 61.0 KB

# %%
mydata.head()
# Out:
#                  AAPL        WMT        RBC      F        AMZN
# Date
# 2016-01-04  26.337500  61.459999  57.820000  13.97  636.989990
# 2016-01-05  25.677500  62.919998  57.310001  13.72  633.789978
# 2016-01-06  25.174999  63.549999  55.470001  13.11  632.650024
# 2016-01-07  24.112499  65.029999  54.610001  12.70  607.940002
# 2016-01-08  24.240000  63.540001  53.669998  12.54  607.049988

# %%
mydata.tail()
# Out:
#                   AAPL         WMT         RBC      F         AMZN
# Date
# 2021-03-01  127.790001  131.369995  141.289993  11.98  3146.139893
# 2021-03-02  125.120003  130.110001  139.679993  12.55  3094.530029
# 2021-03-03  122.059998  127.589996  137.960007  12.17  3005.000000
# 2021-03-04  120.129997  127.529999  135.970001  11.93  2977.570068
# 2021-03-05  120.980003  129.630005  138.154999  12.19  2987.239990

# %%
mydata.plot(figsize = (15, 6))
plt.show()

# %% [markdown]
# ### Normalization to 100:
#
# $$
# \frac {P_t}{P_0} * 100
# $$

# %%
mydata.iloc[0]
# Out:
# AAPL     26.337500
# WMT      61.459999
# RBC      57.820000
# F        13.970000
# AMZN    636.989990
# Name: 2016-01-04 00:00:00, dtype: float64

# %%
(mydata / mydata.iloc[0] * 100).plot(figsize = (15, 6));
plt.show()

# %% [markdown]
# *****

# %% [markdown]
# Calculating the Return

# %%
returns = (mydata / mydata.shift(1)) - 1
returns.head()
# Out:
#                 AAPL       WMT       RBC         F      AMZN
# Date
# 2016-01-04       NaN       NaN       NaN       NaN       NaN
# 2016-01-05 -0.025059  0.023755 -0.008820 -0.017895 -0.005024
# 2016-01-06 -0.019570  0.010013 -0.032106 -0.044461 -0.001799
# 2016-01-07 -0.042205  0.023289 -0.015504 -0.031274 -0.039058
# 2016-01-08  0.005288 -0.022912 -0.017213 -0.012598 -0.001464

# %%
change=mydata.pct_change()
change.head()
# Out:
#                 AAPL       WMT       RBC         F      AMZN
# Date
# 2016-01-04       NaN       NaN       NaN       NaN       NaN
# 2016-01-05 -0.025059  0.023755 -0.008820 -0.017895 -0.005024
# 2016-01-06 -0.019570  0.010013 -0.032106 -0.044461 -0.001799
# 2016-01-07 -0.042205  0.023289 -0.015504 -0.031274 -0.039058
# 2016-01-08  0.005288 -0.022912 -0.017213 -0.012598 -0.001464

# %% [markdown]
# First, assume you would like to create an equally-weighted portfolio. Create the array, naming it “weights”.
#
# Make sre portfolios weight must sum up to 1

# %%
weights = np.array([0.20, 0.20, 0.20, 0.20, 0.20])

# %%
annual_returns = returns.mean() * 250
annual_returns
# Out:
# AAPL    0.338743
# WMT     0.167963
# RBC     0.220120
# F       0.031689
# AMZN    0.342198
# dtype: float64

# %%
np.dot(annual_returns, weights)
# Out:
# 0.22014284403738527

# %%
pfolio_1 = str(round(np.dot(annual_returns, weights), 5) * 100) + ' %'
print (pfolio_1)
# Out:
# 22.014 %

# %%
weights_2 = np.array([0.20, 0.05, 0.15, 0.20, 0.40])

# %%
pfolio_2 = str(round(np.dot(annual_returns, weights_2), 5) * 100) + ' %'
print ('pfolio_2 is '+pfolio_2)
print ('pfolio_1 is '+ pfolio_1)
# Out:
# pfolio_2 is 25.238 %
# pfolio_1 is 22.014 %
